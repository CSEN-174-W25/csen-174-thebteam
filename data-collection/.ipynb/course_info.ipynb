# %% [markdown]
# # Imports

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %% [markdown]
# # 1. Create URL map

# %%
# base URL 
base = 'https://www.scu.edu/bulletin/undergraduate/'

# %%
# Send a GET request to fetch the page content
response = requests.get(base)

# Check if the request was successful
if response.status_code == 200:
    page_content = response.text
else:
    print(f"Failed to retrieve content from {base}")
    exit()

# Create a BeautifulSoup object to parse the HTML content
soup = BeautifulSoup(page_content, 'html.parser')

# Initialize an empty list to store course details
courses = []

# %%
print(soup)
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <title>SCU Undergraduate Bulletin 2024-25 - </title>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <link href="https://cdn.jsdelivr.net/npm/bootstrap@4.6.2/dist/css/bootstrap.min.css" rel="stylesheet"/>
# <script src="https://cdn.jsdelivr.net/npm/jquery@3.6.4/dist/jquery.slim.min.js"></script>
# <script src="https://cdn.jsdelivr.net/npm/popper.js@1.16.1/dist/umd/popper.min.js"></script>
# <script src="https://cdn.jsdelivr.net/npm/bootstrap@4.6.2/dist/js/bootstrap.bundle.min.js"></script>
# <link crossorigin="anonymous" href="https://pro.fontawesome.com/releases/v5.15.3/css/all.css" integrity="sha384-iKbFRxucmOHIcpWdX9NTZ5WETOPm0Goy0WmfyNcl52qSYtc2Buk0NCe6jU1sWWNB" rel="stylesheet"/>
# <link href="https://getbootstrap.com/docs/4.0/components/navbar/" rel="canonical"/>
# <link href="https://assets.scu.edu/public/scu-bulletin.css" rel="stylesheet"/>
# <link crossorigin="anonymous" href="https://pro.fontawesome.com/releases/v5.15.3/css/all.css" integrity="sha384-iKbFRxucmOHIcpWdX9NTZ5WETOPm0Goy0WmfyNcl52qSYtc2Buk0NCe6jU1sWWNB" rel="stylesheet"/>
# <style>
# .gdbold {font-weight:700}
# h3 .gdbold {font-weight:500}
# .gditalic {font-style:italic}
# .gduline {text-decoration:underline}
#
# .bttooltip {
#     margin: 30px 0 30px 0;
#     padding: 30px;
#     border-left: 5px solid #ddd;
#     background-color: rgb(164, 219, 232, .5);
#     border-color: #033b4c;
#     border-radius: 4px;
#     color: #033b4c;
#     font-style: italic;
# }
#
#  ol.start>li {
#      list-style-type: decimal !important;
#      margin-left: 20px;
# }
#
# </style>
# </head>
# <body>
# <header class="navbar navbar-expand-md navbar-dark sticky-top" style="background-color:#B30738">
# <span class="navbar-brand d-inline-block align-bottom">
# <img alt="Santa Clara University Mission logo" src="https://assets.scu.edu/public/media/images/scu/mission-light_gmc8i0.png"/> </span>
# <span class="pagetitle"> SCU Undergraduate Bulletin 2024-25 </span>
# <button aria-controls="collapsibleNavbar" aria-expanded="false" aria-label="Toggle navigation" class="navbar-toggler d-flex d-md-none flex-column" data-target="#collapsibleNavbar" data-toggle="collapse" type="button">
# <span class="toggler-icon top-bar"></span>
# <span class="toggler-icon middle-bar"></span>
# <span class="toggler-icon bottom-bar"></span>
# </button>
# </header>
# <div class="container-fluid">
# <div class="row flex-xl-nowrap">
# <div "="" class="col-12 col-md-3 col-xl-2 collapse navbar-collapse bd-sidebar" id="collapsibleNavbar">
# <nav class="bd-links">
# <form action="./search.html" method="get">
# <div class="input-group">
# <input class="form-control" name="q" placeholder="Search the bulletin" type="text"/>
# <div class="input-group-append">
# <button class="btn btn-secondary" type="submit">
# <i aria-hidden="true" class="fa fa-solid fa-search"></i>
# <span class="sr-only">Search</span>
# </button>
# </div>
# </div>
# </form>
# <ul><li id="e070a4787cac"><span class="tocFldr lv-1"><a class="a_e070a4787cac" href="./2024-2025/index.html#e070a4787cac">2024-2025:  Undergraduate  Bulletin</a></span><ul class="bltFolder"></ul><li id="5999574383d7"><span class="tocFldr lv-1"><a class="a_5999574383d7" href="./chapter-1-university-mission/index.html#5999574383d7"> Chapter 1:  University  Mission</a></span><ul class="bltFolder"><li id="dd5c50445b36"><span class="lv-2"><a class="a_dd5c50445b36" href="./chapter-1-university-mission/santa-clara-university.html#dd5c50445b36"> Santa Clara University</a></span><li id="3f81b93f4992"><span class="lv-2"><a class="a_3f81b93f4992" href="./chapter-1-university-mission/academic-programs.html#3f81b93f4992"> Academic Programs</a></span><li id="4c6670fd2265"><span class="lv-2"><a class="a_4c6670fd2265" href="./chapter-1-university-mission/centers-of-distinction.html#4c6670fd2265"> Centers of Distinction</a></span><li id="67ac4cdd0bb9"><span class="lv-2"><a class="a_67ac4cdd0bb9" href="./chapter-1-university-mission/faculty.html#67ac4cdd0bb9"> Faculty</a></span><li id="257a1d692343"><span class="lv-2"><a class="a_257a1d692343" href="./chapter-1-university-mission/student-body.html#257a1d692343"> Student Body</a></span><li id="5d68052938a6"><span class="lv-2"><a class="a_5d68052938a6" href="./chapter-1-university-mission/alumni.html#5d68052938a6"> Alumni</a></span><li id="2e4f85ba6d63"><span class="lv-2"><a class="a_2e4f85ba6d63" href="./chapter-1-university-mission/campus.html#2e4f85ba6d63"> Campus</a></span></li></li></li></li></li></li></li></ul><li id="e4f10dce9fa5"><span class="tocFldr lv-1"><a class="a_e4f10dce9fa5" href="./chapter-2-transformative-experiences-and-learning-resources/index.html#e4f10dce9fa5"> Chapter 2:  Transformative  Experiences  and  Learning  Resources</a></span><ul class="bltFolder"><li id="16f5ff844ed0"><span class="lv-2"><a class="a_16f5ff844ed0" href="./chapter-2-transformative-experiences-and-learning-resources/the-core-curriculum.html#16f5ff844ed0"> The Core Curriculum</a></span><li id="9b73d9c38c45"><span class="lv-2"><a class="a_9b73d9c38c45" href="./chapter-2-transformative-experiences-and-learning-resources/the-residential-experience.html#9b73d9c38c45"> The  Residential  Experience</a></span><li id="e92620416ffb"><span class="lv-2"><a class="a_e92620416ffb" href="./chapter-2-transformative-experiences-and-learning-resources/campus-ministry.html#e92620416ffb"> Campus  Ministry</a></span><li id="30b9546ac7d5"><span class="lv-2"><a class="a_30b9546ac7d5" href="./chapter-2-transformative-experiences-and-learning-resources/global-engagement.html#30b9546ac7d5"> Global  Engagement</a></span><li id="bf00f28b6d57"><span class="lv-2"><a class="a_bf00f28b6d57" href="./chapter-2-transformative-experiences-and-learning-resources/career-center.html#bf00f28b6d57"> Career  Center</a></span><li id="ded689324b77"><span class="lv-2"><a class="a_ded689324b77" href="./chapter-2-transformative-experiences-and-learning-resources/campus-recreation.html#ded689324b77"> Campus  Recreation</a></span><li id="aaba943e574e"><span class="lv-2"><a class="a_aaba943e574e" href="./chapter-2-transformative-experiences-and-learning-resources/intercollegiate-athletics.html#aaba943e574e"> Intercollegiate Athletics</a></span><li id="6cad13390206"><span class="lv-2"><a class="a_6cad13390206" href="./chapter-2-transformative-experiences-and-learning-resources/scu-presents.html#6cad13390206">SCU Presents</a></span><li id="53b1fac11a83"><span class="lv-2"><a class="a_53b1fac11a83" href="./chapter-2-transformative-experiences-and-learning-resources/center-for-student-involvement.html#53b1fac11a83"> Center for  Student  Involvement</a></span><li id="517df9865f08"><span class="lv-2"><a class="a_517df9865f08" href="./chapter-2-transformative-experiences-and-learning-resources/chartered-student-organizations.html#517df9865f08"> Chartered Student Organizations</a></span><li id="3579ce58332a"><span class="lv-2"><a class="a_3579ce58332a" href=" ...
# <li><span class="tocFldr lv-1"><a href="https://www.scu.edu/map">SCU Campus Map</a></span>
# </li></li></li></li></li></li></li></li></li></li></li></li></li></ul>
# </nav>
# </div>
# <main class="col-12 col-md-7 col-xl-7 py-md-3 pl-md-5 bd-content" role="main">
# <div class="plink prev"> </div>
# <div class="plink next"> </div>
# <div style="clear:both"></div>
# <hr/> <!--
# <div class="cover">
# <h1 class="sr-only">SCU Graduate Business Bulletin 2024-25</h1>
# <img src="https://www.scu.edu/media/external/bulletin/GradBusiness_bulletin_cover_24-25.png" style="width:100%" alt="Image of Lucus Hall" />
# </div>
# -->
# <!--
# <div class="cover"  >
# <h1 class="sr-only">SCU Engineering Graduate Bulletin 2024-25</h1>
# <img src="https://www.scu.edu/media/external/bulletin/GradEngineeringBulletinCover_24-25.jpg" style="width:100%" alt="Building of Sobrato Campus for Discovery and Innovation" />
# </div>
# -->
# <div class="cover">
# <h1 class="sr-only">SCU Undergraduate Bulletin 2024-25</h1>
# <img alt="Four Santa Clara University students sitting on outdoor stairs in front of five palm trees" src="https://www.scu.edu/media/external/bulletin/undergrad_bulletin_24-25_cover.jpg" style="width:100%"/>
# </div>
# <hr/>
# </main>
# </div>
# </div>
# <script>
# $(document).ready(function(){
#     $(this).scrollTop(0);
# });
# </script></body></html>

# %%
sidebar = soup.find_all('ul', class_='bltFolder')

for i, elm in enumerate(sidebar):
    print(i, elm)
# Out:
# 0 <ul class="bltFolder"></ul>
# 1 <ul class="bltFolder"><li id="dd5c50445b36"><span class="lv-2"><a class="a_dd5c50445b36" href="./chapter-1-university-mission/santa-clara-university.html#dd5c50445b36"> Santa Clara University</a></span><li id="3f81b93f4992"><span class="lv-2"><a class="a_3f81b93f4992" href="./chapter-1-university-mission/academic-programs.html#3f81b93f4992"> Academic Programs</a></span><li id="4c6670fd2265"><span class="lv-2"><a class="a_4c6670fd2265" href="./chapter-1-university-mission/centers-of-distinction.html#4c6670fd2265"> Centers of Distinction</a></span><li id="67ac4cdd0bb9"><span class="lv-2"><a class="a_67ac4cdd0bb9" href="./chapter-1-university-mission/faculty.html#67ac4cdd0bb9"> Faculty</a></span><li id="257a1d692343"><span class="lv-2"><a class="a_257a1d692343" href="./chapter-1-university-mission/student-body.html#257a1d692343"> Student Body</a></span><li id="5d68052938a6"><span class="lv-2"><a class="a_5d68052938a6" href="./chapter-1-university-mission/alumni.html#5d68052938a6"> Alumni</a></span><li id="2e4f85ba6d63"><span class="lv-2"><a class="a_2e4f85ba6d63" href="./chapter-1-university-mission/campus.html#2e4f85ba6d63"> Campus</a></span></li></li></li></li></li></li></li></ul>
# 2 <ul class="bltFolder"><li id="16f5ff844ed0"><span class="lv-2"><a class="a_16f5ff844ed0" href="./chapter-2-transformative-experiences-and-learning-resources/the-core-curriculum.html#16f5ff844ed0"> The Core Curriculum</a></span><li id="9b73d9c38c45"><span class="lv-2"><a class="a_9b73d9c38c45" href="./chapter-2-transformative-experiences-and-learning-resources/the-residential-experience.html#9b73d9c38c45"> The  Residential  Experience</a></span><li id="e92620416ffb"><span class="lv-2"><a class="a_e92620416ffb" href="./chapter-2-transformative-experiences-and-learning-resources/campus-ministry.html#e92620416ffb"> Campus  Ministry</a></span><li id="30b9546ac7d5"><span class="lv-2"><a class="a_30b9546ac7d5" href="./chapter-2-transformative-experiences-and-learning-resources/global-engagement.html#30b9546ac7d5"> Global  Engagement</a></span><li id="bf00f28b6d57"><span class="lv-2"><a class="a_bf00f28b6d57" href="./chapter-2-transformative-experiences-and-learning-resources/career-center.html#bf00f28b6d57"> Career  Center</a></span><li id="ded689324b77"><span class="lv-2"><a class="a_ded689324b77" href="./chapter-2-transformative-experiences-and-learning-resources/campus-recreation.html#ded689324b77"> Campus  Recreation</a></span><li id="aaba943e574e"><span class="lv-2"><a class="a_aaba943e574e" href="./chapter-2-transformative-experiences-and-learning-resources/intercollegiate-athletics.html#aaba943e574e"> Intercollegiate Athletics</a></span><li id="6cad13390206"><span class="lv-2"><a class="a_6cad13390206" href="./chapter-2-transformative-experiences-and-learning-resources/scu-presents.html#6cad13390206">SCU Presents</a></span><li id="53b1fac11a83"><span class="lv-2"><a class="a_53b1fac11a83" href="./chapter-2-transformative-experiences-and-learning-resources/center-for-student-involvement.html#53b1fac11a83"> Center for  Student  Involvement</a></span><li id="517df9865f08"><span class="lv-2"><a class="a_517df9865f08" href="./chapter-2-transformative-experiences-and-learning-resources/chartered-student-organizations.html#517df9865f08"> Chartered Student Organizations</a></span><li id="3579ce58332a"><span class="lv-2"><a class="a_3579ce58332a" href="./chapter-2-transformative-experiences-and-learning-resources/office-for-multicultural-learning.html#3579ce58332a"> Office for  Multicultural  Learning</a></span><li id="c26b6b109725"><span class="lv-2"><a class="a_c26b6b109725" href="./chapter-2-transformative-experiences-and-learning-resources/university-honors-program.html#c26b6b109725"> University Honors Program</a></span><li id="949f5b3d0472"><span class="lv-2"><a class="a_949f5b3d0472" href="./chapter-2-transformative-experiences-and-learning-resources/lead-scholars-program.html#949f5b3d0472">LEAD Scholars Program</a></span><li id="bb29accd7caf"><span class="lv-2"><a class="a_bb29accd7caf" href="./chapter-2-transformative-experiences-and-learning-resources/office-of-student-fellowships.html#bb29accd7caf"> Office of Student Fellowships</a></span><li id="c8d35d1581ec"><span class="lv-2"><a class="a_c8d35d1581ec" href="./chapter-2-transformative-experiences-and-learning-resources/peer-educator-program.html#c8d35d1581ec"> Peer  Educator  Program</a></span><li id="24966fb5a986"><span class="lv-2"><a class="a_24966fb5a986" href="./chapter-2-transformative-experiences-and-learning-resources/domestic-public-sector-studies-programs.html#24966fb5a986"> Domestic Public Sector Studies Programs</a></span><li id="7c1a3862e8cd"><span class="lv-2"><a class="a_7c1a3862e8cd" href="./chapter-2-transformative-experiences-and-learning-resources/academic-advising-and-learning-resources.html#7c1a3862e8cd"> Academic Advising and Learning Resources</a></span><li id="55c3ad34602e"><span class="lv-2"><a class="a_55c3ad34602e" href="./chapter-2-transformative-experiences-and-learning-resources/the-writing-center.html#55c3ad34602e"> The Writing Center</a></span><li id="50bb07f1ed4d"><span class="lv-2"><a class="a_50bb07f1ed4d" href="./chapter-2-transformativ ...
# 3 <ul class="bltFolder"><li id="02a28019a4b8"><span class="lv-2"><a class="a_02a28019a4b8" href="./chapter-3-college-of-arts-and-sciences/undergraduate-degrees.html#02a28019a4b8"> Undergraduate Degrees</a></span><li id="f7bf97d9b9e0"><span class="lv-2"><a class="a_f7bf97d9b9e0" href="./chapter-3-college-of-arts-and-sciences/anthropology.html#f7bf97d9b9e0"> Anthropology</a></span><li id="f7994386b4fd"><span class="lv-2"><a class="a_f7994386b4fd" href="./chapter-3-college-of-arts-and-sciences/art-and-art-history.html#f7994386b4fd"> Art  and  Art  History</a></span><li id="3aca1358926e"><span class="lv-2"><a class="a_3aca1358926e" href="./chapter-3-college-of-arts-and-sciences/biology.html#3aca1358926e"> Biology</a></span><li id="cb812009d91c"><span class="lv-2"><a class="a_cb812009d91c" href="./chapter-3-college-of-arts-and-sciences/chemistry-and-biochemistry.html#cb812009d91c"> Chemistry and Biochemistry</a></span><li id="07937c069e5d"><span class="lv-2"><a class="a_07937c069e5d" href="./chapter-3-college-of-arts-and-sciences/child-studies.html#07937c069e5d"> Child Studies</a></span><li id="23ebc4ecf83a"><span class="lv-2"><a class="a_23ebc4ecf83a" href="./chapter-3-college-of-arts-and-sciences/classics.html#23ebc4ecf83a"> Classics</a></span><li id="fc3a72b696d8"><span class="lv-2"><a class="a_fc3a72b696d8" href="./chapter-3-college-of-arts-and-sciences/communication.html#fc3a72b696d8"> Communication</a></span><li id="c89c2dd151c8"><span class="lv-2"><a class="a_c89c2dd151c8" href="./chapter-3-college-of-arts-and-sciences/economics.html#c89c2dd151c8"> Economics</a></span><li id="efe14a4896d1"><span class="lv-2"><a class="a_efe14a4896d1" href="./chapter-3-college-of-arts-and-sciences/english.html#efe14a4896d1"> English</a></span><li id="85643ab4ddbb"><span class="lv-2"><a class="a_85643ab4ddbb" href="./chapter-3-college-of-arts-and-sciences/environmental-studies-and-sciences.html#85643ab4ddbb"> Environmental  Studies  and  Sciences</a></span><li id="db9bedbcbb32"><span class="lv-2"><a class="a_db9bedbcbb32" href="./chapter-3-college-of-arts-and-sciences/ethnic-studies.html#db9bedbcbb32"> Ethnic Studies</a></span><li id="81c027c34540"><span class="lv-2"><a class="a_81c027c34540" href="./chapter-3-college-of-arts-and-sciences/gender-and-sexuality-studies.html#81c027c34540"> Gender and Sexuality Studies</a></span><li id="26de42993d7a"><span class="lv-2"><a class="a_26de42993d7a" href="./chapter-3-college-of-arts-and-sciences/history.html#26de42993d7a"> History</a></span><li id="37d707d78140"><span class="lv-2"><a class="a_37d707d78140" href="./chapter-3-college-of-arts-and-sciences/individual-studies.html#37d707d78140"> Individual Studies</a></span><li id="4d8620d8dfad"><span class="lv-2"><a class="a_4d8620d8dfad" href="./chapter-3-college-of-arts-and-sciences/mathematics-and-computer-science.html#4d8620d8dfad"> Mathematics and Computer Science</a></span><li id="0fe0bb2f41c3"><span class="lv-2"><a class="a_0fe0bb2f41c3" href="./chapter-3-college-of-arts-and-sciences/modern-languages-and-literatures.html#0fe0bb2f41c3"> Modern Languages and Literatures</a></span><li id="98b1758c5b3d"><span class="lv-2"><a class="a_98b1758c5b3d" href="./chapter-3-college-of-arts-and-sciences/music.html#98b1758c5b3d"> Music</a></span><li id="cb9f443ad798"><span class="lv-2"><a class="a_cb9f443ad798" href="./chapter-3-college-of-arts-and-sciences/neuroscience.html#cb9f443ad798"> Neuroscience</a></span><li id="2e5728c8beb5"><span class="lv-2"><a class="a_2e5728c8beb5" href="./chapter-3-college-of-arts-and-sciences/philosophy.html#2e5728c8beb5"> Philosophy</a></span><li id="6598cf74a8fa"><span class="lv-2"><a class="a_6598cf74a8fa" href="./chapter-3-college-of-arts-and-sciences/physics.html#6598cf74a8fa"> Physics</a></span><li id="f2580432317e"><span class="lv-2"><a class="a_f2580432317e" href="./chapter-3-college-of-arts-and-sciences/political-science.html#f2580432317e"> Political Science</a></span><li id="cbd09cb3c353"><span class="lv-2"><a class="a_cbd ...
# 4 <ul class="bltFolder"><li id="fe712c3a9716"><span class="lv-2"><a class="a_fe712c3a9716" href="./chapter-4-leavey-school-of-business/undergraduate-degrees.html#fe712c3a9716"> Undergraduate Degrees</a></span><li id="eb56a77fda85"><span class="lv-2"><a class="a_eb56a77fda85" href="./chapter-4-leavey-school-of-business/centers-institutes-and-special-programs.html#eb56a77fda85"> Centers Institutes and Special Programs</a></span><li id="88aede57b843"><span class="lv-2"><a class="a_88aede57b843" href="./chapter-4-leavey-school-of-business/accounting.html#88aede57b843"> Accounting</a></span><li id="0b4e62ee6c48"><span class="lv-2"><a class="a_0b4e62ee6c48" href="./chapter-4-leavey-school-of-business/economics.html#0b4e62ee6c48"> Economics</a></span><li id="7428eed349a9"><span class="lv-2"><a class="a_7428eed349a9" href="./chapter-4-leavey-school-of-business/finance.html#7428eed349a9"> Finance </a></span><li id="0ee82f124271"><span class="lv-2"><a class="a_0ee82f124271" href="./chapter-4-leavey-school-of-business/management.html#0ee82f124271"> Management</a></span><li id="5e445d7bc235"><span class="lv-2"><a class="a_5e445d7bc235" href="./chapter-4-leavey-school-of-business/marketing.html#5e445d7bc235"> Marketing</a></span><li id="25ebf5158560"><span class="lv-2"><a class="a_25ebf5158560" href="./chapter-4-leavey-school-of-business/information-systems-analytics.html#25ebf5158560"> Information  Systems &amp;  Analytics</a></span><li id="e14ad917a964"><span class="lv-2"><a class="a_e14ad917a964" href="./chapter-4-leavey-school-of-business/entrepreneurship.html#e14ad917a964"> Entrepreneurship</a></span><li id="0df3c5e2a1e5"><span class="lv-2"><a class="a_0df3c5e2a1e5" href="./chapter-4-leavey-school-of-business/international-business.html#0df3c5e2a1e5"> International Business</a></span><li id="bb8a363b267a"><span class="lv-2"><a class="a_bb8a363b267a" href="./chapter-4-leavey-school-of-business/retail-studies.html#bb8a363b267a"> Retail Studies</a></span><li id="b49585ba1534"><span class="lv-2"><a class="a_b49585ba1534" href="./chapter-4-leavey-school-of-business/sustainable-food-systems.html#b49585ba1534"> Sustainable  Food  Systems</a></span></li></li></li></li></li></li></li></li></li></li></li></li></ul>
# 5 <ul class="bltFolder"><li id="54b1f7d6146d"><span class="lv-2"><a class="a_54b1f7d6146d" href="./chapter-5-school-of-engineering/undergraduate-degrees.html#54b1f7d6146d"> Undergraduate Degrees</a></span><li id="7a1e62c24c52"><span class="lv-2"><a class="a_7a1e62c24c52" href="./chapter-5-school-of-engineering/centers-institutes-and-special-programs.html#7a1e62c24c52"> Centers Institutes and Special Programs</a></span><li id="8a4314efc9cf"><span class="lv-2"><a class="a_8a4314efc9cf" href="./chapter-5-school-of-engineering/applied-mathematics.html#8a4314efc9cf"> Applied Mathematics</a></span><li id="9cccaee2d064"><span class="lv-2"><a class="a_9cccaee2d064" href="./chapter-5-school-of-engineering/bioengineering.html#9cccaee2d064"> Bioengineering</a></span><li id="ebcacb23ca46"><span class="lv-2"><a class="a_ebcacb23ca46" href="./chapter-5-school-of-engineering/civil-environmental-and-sustainable-engineering.html#ebcacb23ca46"> Civil, Environmental, and Sustainable  Engineering</a></span><li id="59ffa8ec905c"><span class="lv-2"><a class="a_59ffa8ec905c" href="./chapter-5-school-of-engineering/computer-science-and-engineering.html#59ffa8ec905c"> Computer  Science  and  Engineering</a></span><li id="95e2098e168c"><span class="lv-2"><a class="a_95e2098e168c" href="./chapter-5-school-of-engineering/electrical-and-computer-engineering.html#95e2098e168c"> Electrical and Computer Engineering</a></span><li id="f9a9769c11c2"><span class="lv-2"><a class="a_f9a9769c11c2" href="./chapter-5-school-of-engineering/general-engineering.html#f9a9769c11c2"> General Engineering</a></span><li id="a358a81067c1"><span class="lv-2"><a class="a_a358a81067c1" href="./chapter-5-school-of-engineering/mechanical-engineering.html#a358a81067c1"> Mechanical  Engineering</a></span></li></li></li></li></li></li></li></li></li></ul>
# 6 <ul class="bltFolder"><li id="7484e788de5a"><span class="lv-2"><a class="a_7484e788de5a" href="./chapter-6-university-programs/aerospace-studies.html#7484e788de5a"> Aerospace Studies</a></span><li id="517aabb1e1c5"><span class="lv-2"><a class="a_517aabb1e1c5" href="./chapter-6-university-programs/experiential-learning-for-social-justice.html#517aabb1e1c5"> Experiential  Learning for  Social  Justice</a></span><li id="58c0d7fff35b"><span class="lv-2"><a class="a_58c0d7fff35b" href="./chapter-6-university-programs/lead-scholars-program.html#58c0d7fff35b">LEAD Scholars Program</a></span><li id="280f0b1410a2"><span class="lv-2"><a class="a_280f0b1410a2" href="./chapter-6-university-programs/military-science-program.html#280f0b1410a2"> Military Science Program</a></span><li id="0ebd1590d8b8"><span class="lv-2"><a class="a_0ebd1590d8b8" href="./chapter-6-university-programs/study-abroad-and-global-programs.html#0ebd1590d8b8"> Study Abroad and Global Programs</a></span><li id="f28f4f303302"><span class="lv-2"><a class="a_f28f4f303302" href="./chapter-6-university-programs/summer-sessions.html#f28f4f303302"> Summer Sessions</a></span><li id="71282bc51aec"><span class="lv-2"><a class="a_71282bc51aec" href="./chapter-6-university-programs/university-honors-program.html#71282bc51aec"> University Honors Program</a></span></li></li></li></li></li></li></li></ul>
# 7 <ul class="bltFolder"></ul>
# 8 <ul class="bltFolder"><li id="97b14eb55dee"><span class="lv-2"><a class="a_97b14eb55dee" href="./chapter-8-academic-and-administrative-policies-and-regulations/degree-requirements.html#97b14eb55dee"> Degree Requirements</a></span><li id="924f2523928c"><span class="lv-2"><a class="a_924f2523928c" href="./chapter-8-academic-and-administrative-policies-and-regulations/academic-program-policies-and-regulations.html#924f2523928c"> Academic Program Policies and Regulations</a></span><li id="89977d6a9a91"><span class="lv-2"><a class="a_89977d6a9a91" href="./chapter-8-academic-and-administrative-policies-and-regulations/registration-policies-and-regulations.html#89977d6a9a91"> Registration Policies and Regulations</a></span><li id="744a029c2094"><span class="lv-2"><a class="a_744a029c2094" href="./chapter-8-academic-and-administrative-policies-and-regulations/grading-policies-and-regulations.html#744a029c2094"> Grading Policies and Regulations</a></span><li id="8d1ac06be106"><span class="lv-2"><a class="a_8d1ac06be106" href="./chapter-8-academic-and-administrative-policies-and-regulations/academic-standing-and-student-classification.html#8d1ac06be106"> Academic Standing and Student Classification</a></span><li id="2aaa79f3ad93"><span class="lv-2"><a class="a_2aaa79f3ad93" href="./chapter-8-academic-and-administrative-policies-and-regulations/academic-credit-evaluation.html#2aaa79f3ad93"> Academic Credit Evaluation</a></span><li id="47f325ea282c"><span class="lv-2"><a class="a_47f325ea282c" href="./chapter-8-academic-and-administrative-policies-and-regulations/non-degree-students.html#47f325ea282c"> Non Degree Students</a></span><li id="b14ad9b85bcc"><span class="lv-2"><a class="a_b14ad9b85bcc" href="./chapter-8-academic-and-administrative-policies-and-regulations/academic-integrity.html#b14ad9b85bcc"> Academic Integrity</a></span><li id="5a92ffe142a4"><span class="lv-2"><a class="a_5a92ffe142a4" href="./chapter-8-academic-and-administrative-policies-and-regulations/patent-policy.html#5a92ffe142a4"> Patent Policy</a></span><li id="feb877c1bca7"><span class="lv-2"><a class="a_feb877c1bca7" href="./chapter-8-academic-and-administrative-policies-and-regulations/administrative-policies-and-regulations.html#feb877c1bca7"> Administrative Policies and Regulations</a></span></li></li></li></li></li></li></li></li></li></li></ul>
# 9 <ul class="bltFolder"></ul>
# 10 <ul class="bltFolder"></ul>
# 11 <ul class="bltFolder"><li id="4ccd72a3bc78"><span class="lv-2"><a class="a_4ccd72a3bc78" href="./appendices/academic-accreditations.html#4ccd72a3bc78"> Academic Accreditations</a></span><li id="83264cc30f12"><span class="lv-2"><a class="a_83264cc30f12" href="./appendices/board-of-trustees.html#83264cc30f12"> Board of Trustees</a></span><li id="58c95719b3b7"><span class="lv-2"><a class="a_58c95719b3b7" href="./appendices/board-of-regents.html#58c95719b3b7"> Board of Regents</a></span><li id="33d04e49140a"><span class="lv-2"><a class="a_33d04e49140a" href="./appendices/senior-leadership.html#33d04e49140a"> Senior Leadership</a></span><li id="be18ec412d40"><span class="lv-2"><a class="a_be18ec412d40" href="./appendices/faculty.html#be18ec412d40"> Faculty</a></span></li></li></li></li></li></ul>

# %%
college_tag = {
    'CAS': sidebar[3],
    'LSB': sidebar[4],
    'SOE': sidebar[5]
}

print(type(sidebar[0]))
# Out:
# <class 'bs4.element.Tag'>

# %%
url_map = {}
skip = set([
    ' Undergraduate Degrees',
    ' Centers Institutes and Special Programs'
])

for college, tag in college_tag.items(): 
    print(college)
    for anchor in tag.find_all('a'):
        department = anchor.get_text()
        if department in skip: 
            continue

        url = base + anchor.get('href')[2:]

        url_map[(college, department)] = url

        print('\t', department, ':', url) 

    print('')
# Out:
# CAS
# 	  Anthropology : https://www.scu.edu/bulletin/undergraduate/chapter-3-college-of-arts-and-sciences/anthropology.html#f7bf97d9b9e0
# 	  Art  and  Art  History : https://www.scu.edu/bulletin/undergraduate/chapter-3-college-of-arts-and-sciences/art-and-art-history.html#f7994386b4fd
# 	  Biology : https://www.scu.edu/bulletin/undergraduate/chapter-3-college-of-arts-and-sciences/biology.html#3aca1358926e
# 	  Chemistry and Biochemistry : https://www.scu.edu/bulletin/undergraduate/chapter-3-college-of-arts-and-sciences/chemistry-and-biochemistry.html#cb812009d91c
# 	  Child Studies : https://www.scu.edu/bulletin/undergraduate/chapter-3-college-of-arts-and-sciences/child-studies.html#07937c069e5d
# 	  Classics : https://www.scu.edu/bulletin/undergraduate/chapter-3-college-of-arts-and-sciences/classics.html#23ebc4ecf83a
# 	  Communication : https://www.scu.edu/bulletin/undergraduate/chapter-3-college-of-arts-and-sciences/communication.html#fc3a72b696d8
# 	  Economics : https://www.scu.edu/bulletin/undergraduate/chapter-3-college-of-arts-and-sciences/economics.html#c89c2dd151c8
# 	  English : https://www.scu.edu/bulletin/undergraduate/chapter-3-college-of-arts-and-sciences/english.html#efe14a4896d1
# 	  Environmental  Studies  and  Sciences : https://www.scu.edu/bulletin/undergraduate/chapter-3-college-of-arts-and-sciences/environmental-studies-and-sciences.html#85643ab4ddbb
# 	  Ethnic Studies : https://www.scu.edu/bulletin/undergraduate/chapter-3-college-of-arts-and-sciences/ethnic-studies.html#db9bedbcbb32
# 	  Gender and Sexuality Studies : https://www.scu.edu/bulletin/undergraduate/chapter-3-college-of-arts-and-sciences/gender-and-sexuality-studies.html#81c027c34540
# 	  History : https://www.scu.edu/bulletin/undergraduate/chapter-3-college-of-arts-and-sciences/history.html#26de42993d7a
# 	  Individual Studies : https://www.scu.edu/bulletin/undergraduate/chapter-3-college-of-arts-and-sciences/individual-studies.html#37d707d78140
# 	  Mathematics and Computer Science : https://www.scu.edu/bulletin/undergraduate/chapter-3-college-of-arts-and-sciences/mathematics-and-computer-science.html#4d8620d8dfad
# 	  Modern Languages and Literatures : https://www.scu.edu/bulletin/undergraduate/chapter-3-college-of-arts-and-sciences/modern-languages-and-literatures.html#0fe0bb2f41c3
# 	  Music : https://www.scu.edu/bulletin/undergraduate/chapter-3-college-of-arts-and-sciences/music.html#98b1758c5b3d
# 	  Neuroscience : https://www.scu.edu/bulletin/undergraduate/chapter-3-college-of-arts-and-sciences/neuroscience.html#cb9f443ad798
# 	  Philosophy : https://www.scu.edu/bulletin/undergraduate/chapter-3-college-of-arts-and-sciences/philosophy.html#2e5728c8beb5
# 	  Physics : https://www.scu.edu/bulletin/undergraduate/chapter-3-college-of-arts-and-sciences/physics.html#6598cf74a8fa
# 	  Political Science : https://www.scu.edu/bulletin/undergraduate/chapter-3-college-of-arts-and-sciences/political-science.html#f2580432317e
# 	  Psychology : https://www.scu.edu/bulletin/undergraduate/chapter-3-college-of-arts-and-sciences/psychology.html#cbd09cb3c353
# 	  Public  Health  Department : https://www.scu.edu/bulletin/undergraduate/chapter-3-college-of-arts-and-sciences/public-health-department.html#509f0dd05b17
# 	  Religious Studies : https://www.scu.edu/bulletin/undergraduate/chapter-3-college-of-arts-and-sciences/religious-studies.html#846b4ab8c333
# 	  Sociology : https://www.scu.edu/bulletin/undergraduate/chapter-3-college-of-arts-and-sciences/sociology.html#52e73cfac556
# 	  Theatre  and  Dance : https://www.scu.edu/bulletin/undergraduate/chapter-3-college-of-arts-and-sciences/theatre-and-dance.html#8d7a022b0b40
# 	  Arabic Islamic and Middle Eastern Studies : https://www.scu.edu/bulletin/undergraduate/chapter-3-college-of-arts-and-sciences/arabic-islamic-and-middle-eastern-studies.html#abc06ee976b4
# 	  Asian Studies : https://www.scu.edu/bulletin/undergraduate/chapter-3-college-of-arts-and-sciences/asian-studies.html#89124a1b339a
# 	  Biotechnology : https://www.scu.edu/bulletin/undergraduate/chapter-3-college-of-arts-and-sciences/biotechnology.html#9442f7af5e77
# 	  Catholic Studies : https://www.scu.edu/bulletin/undergraduate/chapter-3-college-of-arts-and-sciences/catholic-studies.html#2ae11056eba4
# 	  Gerontology : https://www.scu.edu/bulletin/undergraduate/chapter-3-college-of-arts-and-sciences/gerontology.html#0c47a1ba82cc
# 	  International Studies : https://www.scu.edu/bulletin/undergraduate/chapter-3-college-of-arts-and-sciences/international-studies.html#386d3684e266
# 	  Latin American Studies : https://www.scu.edu/bulletin/undergraduate/chapter-3-college-of-arts-and-sciences/latin-american-studies.html#bb80caa57102
# 	  Medical  and  Health  Humanities  : https://www.scu.edu/bulletin/undergraduate/chapter-3-college-of-arts-and-sciences/medical-and-health-humanities.html#55b3941878ea
# 	  Musical Theatre : https://www.scu.edu/bulletin/undergraduate/chapter-3-college-of-arts-and-sciences/musical-theatre.html#339634e37c1a
# 	  Pre Health Sciences : https://www.scu.edu/bulletin/undergraduate/chapter-3-college-of-arts-and-sciences/pre-health-sciences.html#4766d405b29e
# 	  Pre Law : https://www.scu.edu/bulletin/undergraduate/chapter-3-college-of-arts-and-sciences/pre-law.html#e5732581652f
# 	  Premodern  Studies : https://www.scu.edu/bulletin/undergraduate/chapter-3-college-of-arts-and-sciences/premodern-studies.html#067d0e2bcc5b
# 	  Pre Teaching : https://www.scu.edu/bulletin/undergraduate/chapter-3-college-of-arts-and-sciences/pre-teaching.html#183d3da63088
# 	  Sustainability : https://www.scu.edu/bulletin/undergraduate/chapter-3-college-of-arts-and-sciences/sustainability.html#6ecd3ff74ca4
# 	  Urban Education : https://www.scu.edu/bulletin/undergraduate/chapter-3-college-of-arts-and-sciences/urban-education.html#d630eb7d4fa1
#
# LSB
# 	  Accounting : https://www.scu.edu/bulletin/undergraduate/chapter-4-leavey-school-of-business/accounting.html#88aede57b843
# 	  Economics : https://www.scu.edu/bulletin/undergraduate/chapter-4-leavey-school-of-business/economics.html#0b4e62ee6c48
# 	  Finance  : https://www.scu.edu/bulletin/undergraduate/chapter-4-leavey-school-of-business/finance.html#7428eed349a9
# 	  Management : https://www.scu.edu/bulletin/undergraduate/chapter-4-leavey-school-of-business/management.html#0ee82f124271
# 	  Marketing : https://www.scu.edu/bulletin/undergraduate/chapter-4-leavey-school-of-business/marketing.html#5e445d7bc235
# 	  Information  Systems &  Analytics : https://www.scu.edu/bulletin/undergraduate/chapter-4-leavey-school-of-business/information-systems-analytics.html#25ebf5158560
# 	  Entrepreneurship : https://www.scu.edu/bulletin/undergraduate/chapter-4-leavey-school-of-business/entrepreneurship.html#e14ad917a964
# 	  International Business : https://www.scu.edu/bulletin/undergraduate/chapter-4-leavey-school-of-business/international-business.html#0df3c5e2a1e5
# 	  Retail Studies : https://www.scu.edu/bulletin/undergraduate/chapter-4-leavey-school-of-business/retail-studies.html#bb8a363b267a
# 	  Sustainable  Food  Systems : https://www.scu.edu/bulletin/undergraduate/chapter-4-leavey-school-of-business/sustainable-food-systems.html#b49585ba1534
#
# SOE
# 	  Applied Mathematics : https://www.scu.edu/bulletin/undergraduate/chapter-5-school-of-engineering/applied-mathematics.html#8a4314efc9cf
# 	  Bioengineering : https://www.scu.edu/bulletin/undergraduate/chapter-5-school-of-engineering/bioengineering.html#9cccaee2d064
# 	  Civil, Environmental, and Sustainable  Engineering : https://www.scu.edu/bulletin/undergraduate/chapter-5-school-of-engineering/civil-environmental-and-sustainable-engineering.html#ebcacb23ca46
# 	  Computer  Science  and  Engineering : https://www.scu.edu/bulletin/undergraduate/chapter-5-school-of-engineering/computer-science-and-engineering.html#59ffa8ec905c
# 	  Electrical and Computer Engineering : https://www.scu.edu/bulletin/undergraduate/chapter-5-school-of-engineering/electrical-and-computer-engineering.html#95e2098e168c
# 	  General Engineering : https://www.scu.edu/bulletin/undergraduate/chapter-5-school-of-engineering/general-engineering.html#f9a9769c11c2
# 	  Mechanical  Engineering : https://www.scu.edu/bulletin/undergraduate/chapter-5-school-of-engineering/mechanical-engineering.html#a358a81067c1

# %% [markdown]
# # 2. Retrieve Course Data

# %%
def get_course_info(soupObj: BeautifulSoup, college, department, show=False):
    content = soupObj.find('body', class_='doc-content')

    col = []
    dep = []
    num = []
    cou = []
    des = []

    next = False
    for elm in content.children:
        if next:
            des.append(elm.get_text())
            
            next = False

            if show:
                print(elm.get_text())

        if elm.name == 'h3':
            arr = elm.get_text().split('.')
            number = arr[0]
            course = ''.join(arr[1:])

            col.append(college)
            dep.append(department)
            num.append(number)
            cou.append(course)

            next = True

            if show:
                print(elm.get_text())

    if next:
        des.append('-')
    
    return col, dep, num, cou, des

# %%
colleges = []
departments = []
numbers = []
courses = []
descriptions = []

for (college, department), url in url_map.items():
    # Send a GET request to fetch the page content
    response = requests.get(url)

    # Check if the request was successful
    if response.status_code == 200:
        page_content = response.text
    else:
        print(f"Failed to retrieve content from {base}")
        exit()

    # Create a BeautifulSoup object to parse the HTML content
    soupObj = BeautifulSoup(page_content, 'html.parser')
    col, dep, num, cou, des = get_course_info(soupObj, college, department)

    colleges += col
    departments += dep
    numbers += num 
    courses += cou
    descriptions += des

# %%
print(len(colleges))
print(len(departments))
print(len(numbers))
print(len(courses))
print(len(descriptions))
# Out:
# 2686
# 2686
# 2686
# 2686
# 2686

# %%
tag_map = {'Anthropology': 'ANTH',
 'Art  and  Art  History': 'ARTH',
 'Biology': 'BIOL',
 'Chemistry and Biochemistry': 'CHEM',
 'Child Studies': 'CHST',
 'Classics': 'CLAS',
 'Communication': 'COMM',
 'Economics': 'ECON',
 'English': 'ENGL',
 'Environmental  Studies  and  Sciences': 'ENVS',
 'Ethnic Studies': 'ETHN',
 'Gender and Sexuality Studies': 'WGST',
 'History': 'HIST',
 'Mathematics and Computer Science': 'MATH',
 'Arabic Studies': 'ARAB',
 'Chinese Studies': 'CHIN',
 'French Studies': 'FREN',
 'German Studies': 'GERM',
 'Italian Studies': 'ITAL',
 'Japanese Studies': 'JAPN',
 'Spanish Studies': 'SPAN',
 'Music': 'MUSC',
 'Neuroscience': 'NEUR',
 'Philosophy': 'PHIL',
 'Physics': 'PHYS',
 'Political Science': 'POLI',
 'Psychology': 'PSYC',
 'Public  Health  Department': 'PHSC',
 'Scripture and Tradition (SCTR)' : 'SCTR',
 'Theology, Ethics, and Spirituality (TESP)': 'TESP',
 'Religion and Society (RSOC)': 'RSOC',
 'Sociology': 'SOCI',
 'Theatre': 'THTR',
 'Dance': 'DANC',
 'Accounting': 'ACTG',
 'Economics': 'ECON',
 'Finance': 'FNCE',
 'Management': 'MGMT',
 'Marketing': 'MKTG',
 'Information  Systems &  Analytics': 'OMIS',
 'Applied Mathematics': 'AMTH',
 'Bioengineering': 'BIOE',
 'Civil, Environmental, and Sustainable  Engineering': 'CENG',
 'Computer  Science  and  Engineering': 'CSEN',
 'Electrical and Computer Engineering': 'ECEN',
 'General Engineering': 'ENGR',
 'Mechanical  Engineering': 'MECH',
}

# %% [markdown]
# # 3. Create Pandas DF

# %%
course_df = pd.DataFrame({
    'college': colleges,
    'department': departments,
    'number': numbers,
    'course': courses,
    'description': descriptions
})

# %%
course_df
# Out:
#      college                department                             number  \
# 0        CAS              Anthropology  Emphasis Programs in Anthropology
# 1        CAS              Anthropology                                  1
# 2        CAS              Anthropology                                  2
# 3        CAS              Anthropology                                  3
# 4        CAS              Anthropology                                  4
# ...      ...                       ...                                ...
# 2681     SOE   Mechanical  Engineering                                194
# 2682     SOE   Mechanical  Engineering                                195
# 2683     SOE   Mechanical  Engineering                                196
# 2684     SOE   Mechanical  Engineering                                198
# 2685     SOE   Mechanical  Engineering                                199
#
#                                                course  \
# 0
# 1             Introduction to Biological Anthropology
# 2                         Introduction to Archaeology
# 3                  Introduction Cultural Anthropology
# 4             Vanished Peoples and Lost Civilizations
# ...                                               ...
# 2681                         Advanced Design I: Tools
# 2682               Advanced Design II: Implementation
# 2683   Advanced Design III: Completion and Evaluation
# 2684                                Independent Study
# 2685                        Directed Research/Reading
#
#                                             description
# 0     Anthropology majors have the option of complet...
# 1     Using an evolutionary framework, we examine ho...
# 2     How do archaeologists understand the past? Thi...
# 3     This course provides an introduction to the su...
# 4     “Popular archaeology” is addressed by examinin...
# ...                                                 ...
# 2681  Design tools basic to all aspects of mechanica...
# 2682  Implementation of design strategy. Detail desi...
# 2683  Design projects completed, assembled, tested, ...
# 2684           By arrangement with faculty. (1–5 units)
# 2685  Investigation of an engineering problem and wr...
#
# [2686 rows x 5 columns]

# %%
import re
# loop through description and regex parse out the prereqs and ignore coreqs parsing
# create a new column for prereqs
course_df['prereqs'] = None

for i in range(len(course_df)):
    result = re.search(r'Prerequisite[s]*: (.*)', course_df['description'][i])
    if result:
        course_df['prereqs'][i] = result.group(1)
# Out:
# /var/folders/06/53x3b15s3c91qwmv8v5qbx8c0000gn/T/ipykernel_11325/2449215744.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   course_df['prereqs'][i] = result.group(1)
# /var/folders/06/53x3b15s3c91qwmv8v5qbx8c0000gn/T/ipykernel_11325/2449215744.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   course_df['prereqs'][i] = result.group(1)
# /var/folders/06/53x3b15s3c91qwmv8v5qbx8c0000gn/T/ipykernel_11325/2449215744.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   course_df['prereqs'][i] = result.group(1)
# /var/folders/06/53x3b15s3c91qwmv8v5qbx8c0000gn/T/ipykernel_11325/2449215744.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   course_df['prereqs'][i] = result.group(1)
# /var/folders/06/53x3b15s3c91qwmv8v5qbx8c0000gn/T/ipykernel_11325/2449215744.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   course_df['prereqs'][i] = result.group(1)
# /var/folders/06/53x3b15s3c91qwmv8v5qbx8c0000gn/T/ipykernel_11325/2449215744.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   course_df['prereqs'][i] = result.group(1)
# /var/folders/06/53x3b15s3c91qwmv8v5qbx8c0000gn/T/ipykernel_11325/2449215744.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   course_df['prereqs'][i] = result.group(1)
# /var/folders/06/53x3b15s3c91qwmv8v5qbx8c0000gn/T/ipykernel_11325/2449215744.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   course_df['prereqs'][i] = result.group(1)
# /var/folders/06/53x3b15s3c91qwmv8v5qbx8c0000gn/T/ipykernel_11325/2449215744.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   course_df['prereqs'][i] = result.group(1)
# /var/folders/06/53x3b15s3c91qwmv8v5qbx8c0000gn/T/ipykernel_11325/2449215744.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   course_df['prereqs'][i] = result.group(1)
# /var/folders/06/53x3b15s3c91qwmv8v5qbx8c0000gn/T/ipykernel_11325/2449215744.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   course_df['prereqs'][i] = result.group(1)
# /var/folders/06/53x3b15s3c91qwmv8v5qbx8c0000gn/T/ipykernel_11325/2449215744.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   course_df['prereqs'][i] = result.group(1)
# /var/folders/06/53x3b15s3c91qwmv8v5qbx8c0000gn/T/ipykernel_11325/2449215744.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   course_df['prereqs'][i] = result.group(1)
# /var/folders/06/53x3b15s3c91qwmv8v5qbx8c0000gn/T/ipykernel_11325/2449215744.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   course_df['prereqs'][i] = result.group(1)
# /var/folders/06/53x3b15s3c91qwmv8v5qbx8c0000gn/T/ipykernel_11325/2449215744.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   course_df['prereqs'][i] = result.group(1)
# /var/folders/06/53x3b15s3c91qwmv8v5qbx8c0000gn/T/ipykernel_11325/2449215744.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   course_df['prereqs'][i] = result.group(1)
# /var/folders/06/53x3b15s3c91qwmv8v5qbx8c0000gn/T/ipykernel_11325/2449215744.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   course_df['prereqs'][i] = result.group(1)
# /var/folders/06/53x3b15s3c91qwmv8v5qbx8c0000gn/T/ipykernel_11325/2449215744.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   course_df['prereqs'][i] = result.group(1)
# /var/folders/06/53x3b15s3c91qwmv8v5qbx8c0000gn/T/ipykernel_11325/2449215744.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   course_df['prereqs'][i] = result.group(1)
# /var/folders/06/53x3b15s3c91qwmv8v5qbx8c0000gn/T/ipykernel_11325/2449215744.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   course_df['prereqs'][i] = result.group(1)
# /var/folders/06/53x3b15s3c91qwmv8v5qbx8c0000gn/T/ipykernel_11325/2449215744.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   course_df['prereqs'][i] = result.group(1)
# /var/folders/06/53x3b15s3c91qwmv8v5qbx8c0000gn/T/ipykernel_11325/2449215744.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   course_df['prereqs'][i] = result.group(1)
# /var/folders/06/53x3b15s3c91qwmv8v5qbx8c0000gn/T/ipykernel_11325/2449215744.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   course_df['prereqs'][i] = result.group(1)
# /var/folders/06/53x3b15s3c91qwmv8v5qbx8c0000gn/T/ipykernel_11325/2449215744.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   course_df['prereqs'][i] = result.group(1)
# /var/folders/06/53x3b15s3c91qwmv8v5qbx8c0000gn/T/ipykernel_11325/2449215744.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   course_df['prereqs'][i] = result.group(1)
# /var/folders/06/53x3b15s3c91qwmv8v5qbx8c0000gn/T/ipykernel_11325/2449215744.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   course_df['prereqs'][i] = result.group(1)
# /var/folders/06/53x3b15s3c91qwmv8v5qbx8c0000gn/T/ipykernel_11325/2449215744.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   course_df['prereqs'][i] = result.group(1)
# /var/folders/06/53x3b15s3c91qwmv8v5qbx8c0000gn/T/ipykernel_11325/2449215744.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   course_df['prereqs'][i] = result.group(1)
# /var/folders/06/53x3b15s3c91qwmv8v5qbx8c0000gn/T/ipykernel_11325/2449215744.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   course_df['prereqs'][i] = result.group(1)
# /var/folders/06/53x3b15s3c91qwmv8v5qbx8c0000gn/T/ipykernel_11325/2449215744.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   course_df['prereqs'][i] = result.group(1)
# /var/folders/06/53x3b15s3c91qwmv8v5qbx8c0000gn/T/ipykernel_11325/2449215744.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   course_df['prereqs'][i] = result.group(1)
# /var/folders/06/53x3b15s3c91qwmv8v5qbx8c0000gn/T/ipykernel_11325/2449215744.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   course_df['prereqs'][i] = result.group(1)
# /var/folders/06/53x3b15s3c91qwmv8v5qbx8c0000gn/T/ipykernel_11325/2449215744.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   course_df['prereqs'][i] = result.group(1)
# /var/folders/06/53x3b15s3c91qwmv8v5qbx8c0000gn/T/ipykernel_11325/2449215744.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   course_df['prereqs'][i] = result.group(1)
# /var/folders/06/53x3b15s3c91qwmv8v5qbx8c0000gn/T/ipykernel_11325/2449215744.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   course_df['prereqs'][i] = result.group(1)
# /var/folders/06/53x3b15s3c91qwmv8v5qbx8c0000gn/T/ipykernel_11325/2449215744.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   course_df['prereqs'][i] = result.group(1)
# /var/folders/06/53x3b15s3c91qwmv8v5qbx8c0000gn/T/ipykernel_11325/2449215744.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   course_df['prereqs'][i] = result.group(1)
# /var/folders/06/53x3b15s3c91qwmv8v5qbx8c0000gn/T/ipykernel_11325/2449215744.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   course_df['prereqs'][i] = result.group(1)
# /var/folders/06/53x3b15s3c91qwmv8v5qbx8c0000gn/T/ipykernel_11325/2449215744.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   course_df['prereqs'][i] = result.group(1)
# /var/folders/06/53x3b15s3c91qwmv8v5qbx8c0000gn/T/ipykernel_11325/2449215744.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   course_df['prereqs'][i] = result.group(1)
# /var/folders/06/53x3b15s3c91qwmv8v5qbx8c0000gn/T/ipykernel_11325/2449215744.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   course_df['prereqs'][i] = result.group(1)
# /var/folders/06/53x3b15s3c91qwmv8v5qbx8c0000gn/T/ipykernel_11325/2449215744.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   course_df['prereqs'][i] = result.group(1)
# /var/folders/06/53x3b15s3c91qwmv8v5qbx8c0000gn/T/ipykernel_11325/2449215744.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   course_df['prereqs'][i] = result.group(1)
# /var/folders/06/53x3b15s3c91qwmv8v5qbx8c0000gn/T/ipykernel_11325/2449215744.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   course_df['prereqs'][i] = result.group(1)
# /var/folders/06/53x3b15s3c91qwmv8v5qbx8c0000gn/T/ipykernel_11325/2449215744.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   course_df['prereqs'][i] = result.group(1)
# /var/folders/06/53x3b15s3c91qwmv8v5qbx8c0000gn/T/ipykernel_11325/2449215744.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   course_df['prereqs'][i] = result.group(1)
# /var/folders/06/53x3b15s3c91qwmv8v5qbx8c0000gn/T/ipykernel_11325/2449215744.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   course_df['prereqs'][i] = result.group(1)
# /var/folders/06/53x3b15s3c91qwmv8v5qbx8c0000gn/T/ipykernel_11325/2449215744.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   course_df['prereqs'][i] = result.group(1)
# /var/folders/06/53x3b15s3c91qwmv8v5qbx8c0000gn/T/ipykernel_11325/2449215744.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   course_df['prereqs'][i] = result.group(1)
# /var/folders/06/53x3b15s3c91qwmv8v5qbx8c0000gn/T/ipykernel_11325/2449215744.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   course_df['prereqs'][i] = result.group(1)
# /var/folders/06/53x3b15s3c91qwmv8v5qbx8c0000gn/T/ipykernel_11325/2449215744.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   course_df['prereqs'][i] = result.group(1)
# /var/folders/06/53x3b15s3c91qwmv8v5qbx8c0000gn/T/ipykernel_11325/2449215744.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# ...
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   course_df['prereqs'][i] = result.group(1)
# /var/folders/06/53x3b15s3c91qwmv8v5qbx8c0000gn/T/ipykernel_11325/2449215744.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   course_df['prereqs'][i] = result.group(1)
# /var/folders/06/53x3b15s3c91qwmv8v5qbx8c0000gn/T/ipykernel_11325/2449215744.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   course_df['prereqs'][i] = result.group(1)
# /var/folders/06/53x3b15s3c91qwmv8v5qbx8c0000gn/T/ipykernel_11325/2449215744.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   course_df['prereqs'][i] = result.group(1)
# /var/folders/06/53x3b15s3c91qwmv8v5qbx8c0000gn/T/ipykernel_11325/2449215744.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   course_df['prereqs'][i] = result.group(1)
# /var/folders/06/53x3b15s3c91qwmv8v5qbx8c0000gn/T/ipykernel_11325/2449215744.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   course_df['prereqs'][i] = result.group(1)
# /var/folders/06/53x3b15s3c91qwmv8v5qbx8c0000gn/T/ipykernel_11325/2449215744.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   course_df['prereqs'][i] = result.group(1)
# /var/folders/06/53x3b15s3c91qwmv8v5qbx8c0000gn/T/ipykernel_11325/2449215744.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   course_df['prereqs'][i] = result.group(1)
# /var/folders/06/53x3b15s3c91qwmv8v5qbx8c0000gn/T/ipykernel_11325/2449215744.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   course_df['prereqs'][i] = result.group(1)
# /var/folders/06/53x3b15s3c91qwmv8v5qbx8c0000gn/T/ipykernel_11325/2449215744.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   course_df['prereqs'][i] = result.group(1)
# /var/folders/06/53x3b15s3c91qwmv8v5qbx8c0000gn/T/ipykernel_11325/2449215744.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   course_df['prereqs'][i] = result.group(1)
# /var/folders/06/53x3b15s3c91qwmv8v5qbx8c0000gn/T/ipykernel_11325/2449215744.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   course_df['prereqs'][i] = result.group(1)
# /var/folders/06/53x3b15s3c91qwmv8v5qbx8c0000gn/T/ipykernel_11325/2449215744.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   course_df['prereqs'][i] = result.group(1)
# /var/folders/06/53x3b15s3c91qwmv8v5qbx8c0000gn/T/ipykernel_11325/2449215744.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   course_df['prereqs'][i] = result.group(1)
# /var/folders/06/53x3b15s3c91qwmv8v5qbx8c0000gn/T/ipykernel_11325/2449215744.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   course_df['prereqs'][i] = result.group(1)
# /var/folders/06/53x3b15s3c91qwmv8v5qbx8c0000gn/T/ipykernel_11325/2449215744.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   course_df['prereqs'][i] = result.group(1)
# /var/folders/06/53x3b15s3c91qwmv8v5qbx8c0000gn/T/ipykernel_11325/2449215744.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   course_df['prereqs'][i] = result.group(1)
# /var/folders/06/53x3b15s3c91qwmv8v5qbx8c0000gn/T/ipykernel_11325/2449215744.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   course_df['prereqs'][i] = result.group(1)

# %%
# save to csv
course_df.to_csv('courses.csv', index=False)
# Out:
# /var/folders/06/53x3b15s3c91qwmv8v5qbx8c0000gn/T/ipykernel_11325/1979770475.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   course_df['coreqs'][i] = result.group(1)
# /var/folders/06/53x3b15s3c91qwmv8v5qbx8c0000gn/T/ipykernel_11325/1979770475.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   course_df['coreqs'][i] = result.group(1)
# /var/folders/06/53x3b15s3c91qwmv8v5qbx8c0000gn/T/ipykernel_11325/1979770475.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   course_df['coreqs'][i] = result.group(1)
# /var/folders/06/53x3b15s3c91qwmv8v5qbx8c0000gn/T/ipykernel_11325/1979770475.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   course_df['coreqs'][i] = result.group(1)
# /var/folders/06/53x3b15s3c91qwmv8v5qbx8c0000gn/T/ipykernel_11325/1979770475.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   course_df['coreqs'][i] = result.group(1)
# /var/folders/06/53x3b15s3c91qwmv8v5qbx8c0000gn/T/ipykernel_11325/1979770475.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   course_df['coreqs'][i] = result.group(1)
# /var/folders/06/53x3b15s3c91qwmv8v5qbx8c0000gn/T/ipykernel_11325/1979770475.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   course_df['coreqs'][i] = result.group(1)
# /var/folders/06/53x3b15s3c91qwmv8v5qbx8c0000gn/T/ipykernel_11325/1979770475.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   course_df['coreqs'][i] = result.group(1)
# /var/folders/06/53x3b15s3c91qwmv8v5qbx8c0000gn/T/ipykernel_11325/1979770475.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   course_df['coreqs'][i] = result.group(1)
# /var/folders/06/53x3b15s3c91qwmv8v5qbx8c0000gn/T/ipykernel_11325/1979770475.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   course_df['coreqs'][i] = result.group(1)
# /var/folders/06/53x3b15s3c91qwmv8v5qbx8c0000gn/T/ipykernel_11325/1979770475.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   course_df['coreqs'][i] = result.group(1)
# /var/folders/06/53x3b15s3c91qwmv8v5qbx8c0000gn/T/ipykernel_11325/1979770475.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   course_df['coreqs'][i] = result.group(1)
# /var/folders/06/53x3b15s3c91qwmv8v5qbx8c0000gn/T/ipykernel_11325/1979770475.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   course_df['coreqs'][i] = result.group(1)
# /var/folders/06/53x3b15s3c91qwmv8v5qbx8c0000gn/T/ipykernel_11325/1979770475.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   course_df['coreqs'][i] = result.group(1)
# /var/folders/06/53x3b15s3c91qwmv8v5qbx8c0000gn/T/ipykernel_11325/1979770475.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   course_df['coreqs'][i] = result.group(1)
# /var/folders/06/53x3b15s3c91qwmv8v5qbx8c0000gn/T/ipykernel_11325/1979770475.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   course_df['coreqs'][i] = result.group(1)
# /var/folders/06/53x3b15s3c91qwmv8v5qbx8c0000gn/T/ipykernel_11325/1979770475.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   course_df['coreqs'][i] = result.group(1)
# /var/folders/06/53x3b15s3c91qwmv8v5qbx8c0000gn/T/ipykernel_11325/1979770475.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   course_df['coreqs'][i] = result.group(1)
# /var/folders/06/53x3b15s3c91qwmv8v5qbx8c0000gn/T/ipykernel_11325/1979770475.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   course_df['coreqs'][i] = result.group(1)
# /var/folders/06/53x3b15s3c91qwmv8v5qbx8c0000gn/T/ipykernel_11325/1979770475.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   course_df['coreqs'][i] = result.group(1)
# /var/folders/06/53x3b15s3c91qwmv8v5qbx8c0000gn/T/ipykernel_11325/1979770475.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   course_df['coreqs'][i] = result.group(1)
# /var/folders/06/53x3b15s3c91qwmv8v5qbx8c0000gn/T/ipykernel_11325/1979770475.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   course_df['coreqs'][i] = result.group(1)
# /var/folders/06/53x3b15s3c91qwmv8v5qbx8c0000gn/T/ipykernel_11325/1979770475.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   course_df['coreqs'][i] = result.group(1)
# /var/folders/06/53x3b15s3c91qwmv8v5qbx8c0000gn/T/ipykernel_11325/1979770475.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   course_df['coreqs'][i] = result.group(1)
# /var/folders/06/53x3b15s3c91qwmv8v5qbx8c0000gn/T/ipykernel_11325/1979770475.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   course_df['coreqs'][i] = result.group(1)
# /var/folders/06/53x3b15s3c91qwmv8v5qbx8c0000gn/T/ipykernel_11325/1979770475.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   course_df['coreqs'][i] = result.group(1)
# /var/folders/06/53x3b15s3c91qwmv8v5qbx8c0000gn/T/ipykernel_11325/1979770475.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   course_df['coreqs'][i] = result.group(1)
# /var/folders/06/53x3b15s3c91qwmv8v5qbx8c0000gn/T/ipykernel_11325/1979770475.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   course_df['coreqs'][i] = result.group(1)
# /var/folders/06/53x3b15s3c91qwmv8v5qbx8c0000gn/T/ipykernel_11325/1979770475.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   course_df['coreqs'][i] = result.group(1)
# /var/folders/06/53x3b15s3c91qwmv8v5qbx8c0000gn/T/ipykernel_11325/1979770475.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   course_df['coreqs'][i] = result.group(1)
# /var/folders/06/53x3b15s3c91qwmv8v5qbx8c0000gn/T/ipykernel_11325/1979770475.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   course_df['coreqs'][i] = result.group(1)
# /var/folders/06/53x3b15s3c91qwmv8v5qbx8c0000gn/T/ipykernel_11325/1979770475.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   course_df['coreqs'][i] = result.group(1)
# /var/folders/06/53x3b15s3c91qwmv8v5qbx8c0000gn/T/ipykernel_11325/1979770475.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   course_df['coreqs'][i] = result.group(1)
# /var/folders/06/53x3b15s3c91qwmv8v5qbx8c0000gn/T/ipykernel_11325/1979770475.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   course_df['coreqs'][i] = result.group(1)
# /var/folders/06/53x3b15s3c91qwmv8v5qbx8c0000gn/T/ipykernel_11325/1979770475.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   course_df['coreqs'][i] = result.group(1)
# /var/folders/06/53x3b15s3c91qwmv8v5qbx8c0000gn/T/ipykernel_11325/1979770475.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   course_df['coreqs'][i] = result.group(1)
# /var/folders/06/53x3b15s3c91qwmv8v5qbx8c0000gn/T/ipykernel_11325/1979770475.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   course_df['coreqs'][i] = result.group(1)
# /var/folders/06/53x3b15s3c91qwmv8v5qbx8c0000gn/T/ipykernel_11325/1979770475.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   course_df['coreqs'][i] = result.group(1)
# /var/folders/06/53x3b15s3c91qwmv8v5qbx8c0000gn/T/ipykernel_11325/1979770475.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   course_df['coreqs'][i] = result.group(1)
# /var/folders/06/53x3b15s3c91qwmv8v5qbx8c0000gn/T/ipykernel_11325/1979770475.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   course_df['coreqs'][i] = result.group(1)
# /var/folders/06/53x3b15s3c91qwmv8v5qbx8c0000gn/T/ipykernel_11325/1979770475.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   course_df['coreqs'][i] = result.group(1)
# /var/folders/06/53x3b15s3c91qwmv8v5qbx8c0000gn/T/ipykernel_11325/1979770475.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   course_df['coreqs'][i] = result.group(1)
# /var/folders/06/53x3b15s3c91qwmv8v5qbx8c0000gn/T/ipykernel_11325/1979770475.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   course_df['coreqs'][i] = result.group(1)
# /var/folders/06/53x3b15s3c91qwmv8v5qbx8c0000gn/T/ipykernel_11325/1979770475.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   course_df['coreqs'][i] = result.group(1)
# /var/folders/06/53x3b15s3c91qwmv8v5qbx8c0000gn/T/ipykernel_11325/1979770475.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   course_df['coreqs'][i] = result.group(1)
# /var/folders/06/53x3b15s3c91qwmv8v5qbx8c0000gn/T/ipykernel_11325/1979770475.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   course_df['coreqs'][i] = result.group(1)
# /var/folders/06/53x3b15s3c91qwmv8v5qbx8c0000gn/T/ipykernel_11325/1979770475.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   course_df['coreqs'][i] = result.group(1)
# /var/folders/06/53x3b15s3c91qwmv8v5qbx8c0000gn/T/ipykernel_11325/1979770475.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   course_df['coreqs'][i] = result.group(1)
# /var/folders/06/53x3b15s3c91qwmv8v5qbx8c0000gn/T/ipykernel_11325/1979770475.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   course_df['coreqs'][i] = result.group(1)
# /var/folders/06/53x3b15s3c91qwmv8v5qbx8c0000gn/T/ipykernel_11325/1979770475.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   course_df['coreqs'][i] = result.group(1)
# /var/folders/06/53x3b15s3c91qwmv8v5qbx8c0000gn/T/ipykernel_11325/1979770475.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   course_df['coreqs'][i] = result.group(1)
# /var/folders/06/53x3b15s3c91qwmv8v5qbx8c0000gn/T/ipykernel_11325/1979770475.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# ...
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   course_df['coreqs'][i] = result.group(1)
# /var/folders/06/53x3b15s3c91qwmv8v5qbx8c0000gn/T/ipykernel_11325/1979770475.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   course_df['coreqs'][i] = result.group(1)
# /var/folders/06/53x3b15s3c91qwmv8v5qbx8c0000gn/T/ipykernel_11325/1979770475.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   course_df['coreqs'][i] = result.group(1)
# /var/folders/06/53x3b15s3c91qwmv8v5qbx8c0000gn/T/ipykernel_11325/1979770475.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   course_df['coreqs'][i] = result.group(1)
# /var/folders/06/53x3b15s3c91qwmv8v5qbx8c0000gn/T/ipykernel_11325/1979770475.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   course_df['coreqs'][i] = result.group(1)
# /var/folders/06/53x3b15s3c91qwmv8v5qbx8c0000gn/T/ipykernel_11325/1979770475.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   course_df['coreqs'][i] = result.group(1)
# /var/folders/06/53x3b15s3c91qwmv8v5qbx8c0000gn/T/ipykernel_11325/1979770475.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   course_df['coreqs'][i] = result.group(1)
# /var/folders/06/53x3b15s3c91qwmv8v5qbx8c0000gn/T/ipykernel_11325/1979770475.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   course_df['coreqs'][i] = result.group(1)
# /var/folders/06/53x3b15s3c91qwmv8v5qbx8c0000gn/T/ipykernel_11325/1979770475.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   course_df['coreqs'][i] = result.group(1)
# /var/folders/06/53x3b15s3c91qwmv8v5qbx8c0000gn/T/ipykernel_11325/1979770475.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   course_df['coreqs'][i] = result.group(1)
# /var/folders/06/53x3b15s3c91qwmv8v5qbx8c0000gn/T/ipykernel_11325/1979770475.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   course_df['coreqs'][i] = result.group(1)
# /var/folders/06/53x3b15s3c91qwmv8v5qbx8c0000gn/T/ipykernel_11325/1979770475.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   course_df['coreqs'][i] = result.group(1)
# /var/folders/06/53x3b15s3c91qwmv8v5qbx8c0000gn/T/ipykernel_11325/1979770475.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   course_df['coreqs'][i] = result.group(1)
# /var/folders/06/53x3b15s3c91qwmv8v5qbx8c0000gn/T/ipykernel_11325/1979770475.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   course_df['coreqs'][i] = result.group(1)
# /var/folders/06/53x3b15s3c91qwmv8v5qbx8c0000gn/T/ipykernel_11325/1979770475.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   course_df['coreqs'][i] = result.group(1)
# /var/folders/06/53x3b15s3c91qwmv8v5qbx8c0000gn/T/ipykernel_11325/1979770475.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   course_df['coreqs'][i] = result.group(1)
# /var/folders/06/53x3b15s3c91qwmv8v5qbx8c0000gn/T/ipykernel_11325/1979770475.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   course_df['coreqs'][i] = result.group(1)
# /var/folders/06/53x3b15s3c91qwmv8v5qbx8c0000gn/T/ipykernel_11325/1979770475.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   course_df['coreqs'][i] = result.group(1)
